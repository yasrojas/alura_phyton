# %% [markdown]
# <a href="https://colab.research.google.com/github/yasrojas/alura_phyton/blob/main/ImersaoDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao pandas e Matplotlib Pyplot com manipulação de tabelas e gráficos. Dados baseados em um experimento com células.

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 14886a5b2       1
# 6fbceecd4       1
# f2cc15da6       1
# 861a693e3       1
# f5487e91f       1
# Name: droga, Length: 3289, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# ## Plotar as últimas 5 linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# ## Quantos tipos de drogas foram investigados.

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# ## Proporção das classes tratamento

# %%
import matplotlib.pyplot as plt

dados['tratamento'].value_counts().plot.pie(autopct='%1.1f%%', shadow= True)

plt.axis('equal')                                      
plt.title('Gráfico do tratamento')
plt.show()

# %%
import matplotlib.pyplot as plt

dados['tempo'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Gráfico do tempo')
plt.axis('equal')
plt.show()

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
import matplotlib.pyplot as plt

dados['tempo'].value_counts().plot.bar()
plt.title('Gráfico do tempo')
plt.show()

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_filtrados = dados[dados['g-0'] > 0]

# %%
dados_filtrados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dados.columns = dados.columns.str.replace(r'[-]', '_')

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# # Introdução da biblioteca seaborn com matpotlib. Utilização de histogramas, botplox e countplot.

# %%
mapa = {'droga': 'composto'}
dados.rename(columns = mapa, inplace= True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 6))
plt.grid(True)

sns.set()
ax = sns.countplot(x = 'composto', 
                   data = dados.query('composto in @cod_compostos'), 
                   order=dados.query('composto in @cod_compostos').composto.value_counts().index) 
ax.set_title('Top 5 Compostos', fontsize='xx-large', fontweight='bold', pad= 30)
ax.set_xlabel('tipo de composto', fontsize='large', fontstyle= 'italic')
ax.set_ylabel('quantidade de composto', fontsize='large', fontstyle= 'italic')

plt.show()

# %%
len(dados['g_0'].unique())
# Out:
# 14367

# %%
dados['g_0'].min()
# Out:
# -5.513

# %%
dados['g_0'].max()
# Out:
# 10.0

# %%
# dados['g_0'].hist(bins = 100)

ax = sns.histplot(data = dados, x = 'g_0', bins = 100)
ax.set_title('Histograma de g-0', fontsize='xx-large', fontweight='bold', pad= 30)
ax.set_xlabel('valor em g-0', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
# dados['g_19'].hist(bins= 100)


ax = sns.histplot(data = dados, x = 'g_19', bins = 100)
ax.set_title('Histograma de g-19', fontsize='xx-large', fontweight='bold', pad= 30)
ax.set_xlabel('valor em g-19', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
dados.describe()
# Out:
#               tempo           g_0  ...          c_98          c_99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados.loc[:, 'g_0':'g_771'].describe()
# Out:
#                 g_0           g_1  ...         g_770         g_771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
# dados.loc[:, 'g_0':'g_771'].describe().T['mean'].hist(bins=50)

ax = sns.histplot(data = dados, 
                  x = dados.loc[:, 'g_0':'g_771'].describe().T['mean'], 
                  bins = 50,
                  kde= True)
ax.set_title('Histograma da média de g-0 ao g-771', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('valores em g-n', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
# dados.loc[:, 'g_0':'g_771'].describe().T['min'].hist(bins=50)

ax = sns.histplot(data = dados, 
                  x = dados.loc[:, 'g_0':'g_771'].describe().T['min'], 
                  bins = 50)
ax.set_title('Histograma do mínimo de g-0 ao g-771', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('valores em g-n', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
# dados.loc[:, 'g_0':'g_771'].describe().T['max'].hist(bins=50)

ax = sns.histplot(data = dados, 
                  x = dados.loc[:, 'g_0':'g_771'].describe().T['max'], 
                  bins = 50)
ax.set_title('Histograma do máximo de g-0 ao g-771', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('valores em g-n', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
# dados.loc[:, 'c_0':'c_99'].describe().T['mean'].hist(bins=50)

ax = sns.histplot(data = dados, 
                  x = dados.loc[:, 'c_0':'c_99'].describe().T['mean'], 
                  bins = 50)
ax.set_title('Histograma da média de c-0 ao c-99', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('valores em c-n', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
# dados.loc[:, 'g_0':'g_771'].describe().T['min'].hist(bins=50)

ax = sns.histplot(data = dados, 
                  x = dados.loc[:, 'c_0':'c_99'].describe().T['min'], 
                  bins = 50)
ax.set_title('Histograma do mínimo de c-0 ao c-99', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('valores em c-n', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
# dados.loc[:, 'g_0':'g_771'].describe().T['max'].hist(bins=50)

ax = sns.histplot(data = dados, 
                  x = dados.loc[:, 'c_0':'c_99'].describe().T['max'], 
                  bins = 50)
ax.set_title('Histograma do máximo de c-0 ao c-99', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('valores em c-n', fontsize='large')
ax.set_ylabel('quantidade do valor nos dados', fontsize='large')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x= 'g_0', 
                 y = 'tratamento', 
                 data = dados)
ax.set_title('Botplox da relação entre g-0 e tratamento', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('valores em g-0', fontsize='large')
ax.set_ylabel('tipo de tratamento', fontsize='large')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x = 'composto', 
                 y = 'g_0', 
                 data = dados.query('composto in @cod_compostos'))
ax.set_title('Botplox da relação entre g-0 e principais compostos', 
             fontsize='xx-large', 
             fontweight='bold', 
             pad= 30)
ax.set_xlabel('tipo de composto', fontsize='large')
ax.set_ylabel('valor de g-0', fontsize='large')

plt.show()

# %% [markdown]
# ## Explorar o crosstab pela coluna

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ## Criar tabelas de frequência com pandas.groupby()

# %%
df = pd.DataFrame(dados)

grouped = df.groupby(['dose', 'tempo', 'tratamento']).agg({'tratamento': ['count']})
grouped
# Out:
#                         tratamento
#                              count
# dose tempo tratamento
# D1   24    com_controle        301
#            com_droga          3585
#      48    com_controle        343
#            com_droga          4011
#      72    com_controle        307
#            com_droga          3600
# D2   24    com_controle        305
#            com_droga          3581
#      48    com_controle        305
#            com_droga          3591
#      72    com_controle        305
#            com_droga          3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g_0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
df = pd.DataFrame(dados)

grouped1 = df.groupby(['dose', 'tempo', 'tratamento']).agg({'g_0': 'mean'})
grouped1
# Out:
#                               g_0
# dose tempo tratamento
# D1   24    com_controle -0.251760
#            com_droga     0.367996
#      48    com_controle -0.122773
#            com_droga     0.412469
#      72    com_controle -0.295271
#            com_droga     0.286250
# D2   24    com_controle  0.010754
#            com_droga     0.115253
#      48    com_controle  0.013174
#            com_droga     0.214480
#      72    com_controle  0.070250
#            com_droga     0.253439

# %% [markdown]
# ## Explorar o melt

# %%
pd.melt(df, id_vars=['dose', 'tempo', 'tratamento'], value_vars=['g_0'])
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga      g_0  1.0620
# 1       D1     72     com_droga      g_0  0.0743
# 2       D1     48     com_droga      g_0  0.6280
# 3       D1     48     com_droga      g_0 -0.5138
# 4       D2     72     com_droga      g_0 -0.3254
# ...    ...    ...           ...      ...     ...
# 23809   D2     24     com_droga      g_0  0.1394
# 23810   D2     24     com_droga      g_0 -1.3260
# 23811   D2     48  com_controle      g_0  0.3942
# 23812   D1     24     com_droga      g_0  0.6660
# 23813   D1     72     com_droga      g_0 -0.8598
#
# [23814 rows x 5 columns]

# %%
pd.melt(df, id_vars=['dose', 'tempo', 'tratamento'], value_vars=['g_771'])
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga    g_771 -0.0224
# 1       D1     72     com_droga    g_771 -0.2718
# 2       D1     48     com_droga    g_771  0.7923
# 3       D1     48     com_droga    g_771 -0.0343
# 4       D2     72     com_droga    g_771 -0.6269
# ...    ...    ...           ...      ...     ...
# 23809   D2     24     com_droga    g_771  0.3806
# 23810   D2     24     com_droga    g_771 -0.4751
# 23811   D2     48  com_controle    g_771  0.3603
# 23812   D1     24     com_droga    g_771 -0.4741
# 23813   D1     72     com_droga    g_771  2.2190
#
# [23814 rows x 5 columns]

# %%
sns.scatterplot(x='g_0', y='g_3', data=dados)

# %%
sns.scatterplot(x='g_0', y='g_8', data=dados)

# %%
sns.lmplot(data=dados, x='g_0', y='g_8', line_kws={'color': 'red'})

# %%
sns.lmplot(data=dados, x='g_0', y='g_8', line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:, 'g_0':'g_771'].corr()
# Out:
#             g_0       g_1       g_2  ...     g_769     g_770     g_771
# g_0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g_1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g_2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g_3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g_4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g_767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g_768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g_769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g_770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g_771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np

corr = dados.loc[:, 'g_0':'g_50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:, 'c_0':'c_50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Calcular e analisar a correlação entre G e C.

# %%
corr_celular= dados.loc[:, 'c_0':'c_20'].corr()
corr_gene= dados.loc[:, 'g_0':'g_20'].corr()

fig, (ax1, ax2)= plt.subplots(1,2, figsize=(20,10))

ax= sns.heatmap(corr_celular, ax= ax1, square= True, center= 0, vmin= -1, vmax= 1)
ax= sns.heatmap(corr_gene, ax= ax2, square= True, center= 0, vmin= -1, vmax= 1)
plt.show()

# %%
df_celular= dados.loc[:, 'c_0':'c_20']
df_gene= dados.loc[:, 'g_0':'g_20']

result = pd.concat([df_celular, df_gene], axis=1).corr()
result
# Out:
#            c_0       c_1       c_2  ...      g_18      g_19      g_20
# c_0   1.000000  0.827336  0.848472  ... -0.032060  0.078310  0.443028
# c_1   0.827336  1.000000  0.901416  ... -0.071016  0.029949  0.368740
# c_2   0.848472  0.901416  1.000000  ... -0.058010  0.041212  0.407185
# c_3   0.798830  0.808364  0.830759  ... -0.020933  0.076050  0.395583
# c_4   0.840695  0.879258  0.909991  ... -0.068624  0.015357  0.409882
# c_5   0.844469  0.869569  0.882794  ... -0.075409  0.036808  0.418791
# c_6   0.811946  0.876924  0.898819  ... -0.092479  0.019807  0.415082
# c_7   0.793171  0.793199  0.812980  ... -0.039252  0.052146  0.442555
# c_8   0.842977  0.879892  0.896087  ... -0.062927  0.033836  0.412023
# c_9   0.759971  0.812345  0.821522  ... -0.081161 -0.003701  0.415648
# c_10  0.850533  0.866297  0.892033  ... -0.091117  0.030335  0.456595
# c_11  0.832837  0.884532  0.904968  ... -0.049058  0.036885  0.428794
# ...

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultados.drop('id', axis= 1).sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.columns.values
# Out:
# array(['id', '5-alpha_reductase_inhibitor', '11-beta-hsd1_inhibitor',
#        'acat_inhibitor', 'acetylcholine_receptor_agonist',
#        'acetylcholine_receptor_antagonist',
#        'acetylcholinesterase_inhibitor', 'adenosine_receptor_agonist',
#        'adenosine_receptor_antagonist', 'adenylyl_cyclase_activator',
#        'adrenergic_receptor_agonist', 'adrenergic_receptor_antagonist',
#        'akt_inhibitor', 'aldehyde_dehydrogenase_inhibitor',
#        'alk_inhibitor', 'ampk_activator', 'analgesic',
#        'androgen_receptor_agonist', 'androgen_receptor_antagonist',
#        'anesthetic_-_local', 'angiogenesis_inhibitor',
#        'angiotensin_receptor_antagonist', 'anti-inflammatory',
#        'antiarrhythmic', 'antibiotic', 'anticonvulsant', 'antifungal',
#        'antihistamine', 'antimalarial', 'antioxidant', 'antiprotozoal',
#        'antiviral', 'apoptosis_stimulant', 'aromatase_inhibitor',
#        'atm_kinase_inhibitor',
# ...

# %%
inibidores = dados_resultados.select_dtypes('int64').sum()
inibidores.filter(like='inhibitor').sort_values(ascending = False).head(10)
# Out:
# nfkb_inhibitor              832
# proteasome_inhibitor        726
# cyclooxygenase_inhibitor    435
# dna_inhibitor               402
# cdk_inhibitor               340
# egfr_inhibitor              336
# tubulin_inhibitor           316
# pdgfr_inhibitor             297
# hmgcr_inhibitor             283
# flt3_inhibitor              279
# dtype: int64

# %% [markdown]
# ## Encontrar o top 10 das ações do MDA(inibidor, agonista...)

# %%
agonistas = dados_resultados.select_dtypes('int64').sum()
agonistas.filter(like='agonist').sort_values(ascending = False).head(10)
# Out:
# dopamine_receptor_antagonist         424
# serotonin_receptor_antagonist        404
# glutamate_receptor_antagonist        367
# adrenergic_receptor_antagonist       360
# acetylcholine_receptor_antagonist    301
# adrenergic_receptor_agonist          270
# glucocorticoid_receptor_agonist      266
# histamine_receptor_antagonist        241
# serotonin_receptor_agonist           236
# acetylcholine_receptor_agonist       190
# dtype: int64

# %%
antagonistas = dados_resultados.select_dtypes('int64').sum()
antagonistas.filter(like='antagonist').sort_values(ascending = False).head(10)
# Out:
# dopamine_receptor_antagonist         424
# serotonin_receptor_antagonist        404
# glutamate_receptor_antagonist        367
# adrenergic_receptor_antagonist       360
# acetylcholine_receptor_antagonist    301
# histamine_receptor_antagonist        241
# gaba_receptor_antagonist             165
# cc_chemokine_receptor_antagonist     102
# potassium_channel_antagonist          98
# opioid_receptor_antagonist            96
# dtype: int64

# %%
ativadores = dados_resultados.select_dtypes('int64').sum()
ativadores.filter(like='activator').sort_values(ascending = False).head(10)
# Out:
# potassium_channel_activator    55
# nrf2_activator                 18
# caspase_activator              18
# ampk_activator                 12
# adenylyl_cyclase_activator     12
# dtype: int64

# %%
analgesico = dados_resultados.select_dtypes('int64').sum()
analgesico.filter(items=['analgesic'])
# Out:
# analgesic    12
# dtype: int64

# %%
anestesico_local = dados_resultados.select_dtypes('int64').sum()
anestesico_local.filter(items=['anesthetic_-_local'])
# Out:
# anesthetic_-_local    80
# dtype: int64

# %%
anti = dados_resultados.select_dtypes('int64').sum()
anti.filter(like='anti').sort_values(ascending = False).head(10)
# Out:
# antioxidant             73
# anti-inflammatory       73
# antibiotic              43
# bacterial_antifolate    36
# antiprotozoal           36
# antiviral               23
# antimalarial            18
# antifungal              13
# antihistamine           12
# anticonvulsant          12
# dtype: int64

# %%
estimulante_apoptose = dados_resultados.select_dtypes('int64').sum()
estimulante_apoptose.filter(items=['apoptosis_stimulant'])
# Out:
# apoptosis_stimulant    49
# dtype: int64

# %%
bloqueadores = dados_resultados.select_dtypes('int64').sum()
bloqueadores.filter(like='blocker').sort_values(ascending = False)
# Out:
# calcium_channel_blocker     281
# chloride_channel_blocker     42
# dtype: int64

# %%
diuretico = dados_resultados.select_dtypes('int64').sum()
diuretico.filter(items=['diuretic'])
# Out:
# diuretic    6
# dtype: int64

# %%
free_radical_scavenger = dados_resultados.select_dtypes('int64').sum()
free_radical_scavenger.filter(items=['free_radical_scavenger'])
# Out:
# free_radical_scavenger    18
# dtype: int64

# %%
imunosupressante = dados_resultados.select_dtypes('int64').sum()
imunosupressante.filter(items=['immunosuppressant'])
# Out:
# immunosuppressant    73
# dtype: int64

# %%
insulina = dados_resultados.select_dtypes('int64').sum()
insulina.filter(like='insulin').sort_values(ascending = False).head(10)
# Out:
# insulin_sensitizer      51
# insulin_secretagogue    30
# dtype: int64

# %%
nitric_oxide_donor = dados_resultados.select_dtypes('int64').sum()
nitric_oxide_donor.filter(items=['nitric_oxide_donor'])
# Out:
# nitric_oxide_donor    26
# dtype: int64

# %%
radiopaque_medium = dados_resultados.select_dtypes('int64').sum()
radiopaque_medium.filter(items=['radiopaque_medium'])
# Out:
# radiopaque_medium    56
# dtype: int64

# %%
esteroide = dados_resultados.select_dtypes('int64').sum()
esteroide.filter(items=['steroid'])
# Out:
# steroid    6
# dtype: int64

# %%
vitamina_b = dados_resultados.select_dtypes('int64').sum()
vitamina_b.filter(items=['vitamin_b'])
# Out:
# vitamin_b    26
# dtype: int64

# %%
dados_resultados.drop('id', axis= 1).sum(axis= 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis= 1).sum(axis= 1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c_98    c_99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# ## Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == "com_controle")
dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     1      True        False
# 1      id_000779bfc     com_droga     72  ...     0     False        False
# 2      id_000a6266a     com_droga     48  ...     3      True        False
# 3      id_0015fd391     com_droga     48  ...     0     False        False
# 4      id_001626bd3     com_droga     72  ...     1      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     1      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# ## Criar três colunas para indicar se o tempo  foi de 24, 48 ou 72 horas.

# %%
dados_combinados['tempo_24'] = (dados_combinados['tempo'] == 24)
dados_combinados['tempo_48'] = (dados_combinados['tempo'] == 48)
dados_combinados['tempo_72'] = (dados_combinados['tempo'] == 72)

dados_combinados.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
#
# [5 rows x 883 columns]

# %% [markdown]
# ## Estudar sobre combinações de DF: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
compostos_principais = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @compostos_principais'), 
            y='g_0', x='composto', hue='ativo_moa')

# %% [markdown]
# ## Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @compostos_principais'), 
            y='g_0', x='composto', hue='dose')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @compostos_principais'), 
            y='g_0', x='composto', hue='tempo')

# %% [markdown]
# ## Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
compostos_principais
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
compostos_ativo_moa = dados_combinados.query('composto in @compostos_principais')[['composto','ativo_moa', 'dose', 'tempo']]
compostos_ativo_moa
# Out:
#         composto  ativo_moa dose  tempo
# 7      8b87a7a83       True   D1     48
# 16     87d714366       True   D1     48
# 25     cacb2b860      False   D1     48
# 38     cacb2b860      False   D1     24
# 40     cacb2b860      False   D2     24
# ...          ...        ...  ...    ...
# 23793  cacb2b860      False   D2     48
# 23802  87d714366       True   D1     24
# 23805  5628cb3ee       True   D2     48
# 23811  cacb2b860      False   D2     48
# 23812  8b87a7a83       True   D1     24
#
# [3235 rows x 4 columns]

# %%
compostos_ativo_moa.query('composto == "8b87a7a83" & ativo_moa != True')
# Out:
# Empty DataFrame
# Columns: [composto, ativo_moa, dose, tempo]
# Index: []

# %%
compostos_ativo_moa.query('composto == "87d714366" & ativo_moa != True')
# Out:
# Empty DataFrame
# Columns: [composto, ativo_moa, dose, tempo]
# Index: []

# %%
compostos_ativo_moa.query('composto == "cacb2b860" & ativo_moa != False')
# Out:
# Empty DataFrame
# Columns: [composto, ativo_moa, dose, tempo]
# Index: []

# %%
compostos_ativo_moa.query('composto == "9f80f3f77" & ativo_moa != True')
# Out:
# Empty DataFrame
# Columns: [composto, ativo_moa, dose, tempo]
# Index: []

# %% [markdown]
# ## Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %%
compostos_n_moa = dados_combinados.query('composto in @compostos_principais')[['composto','n_moa', 'dose', 'tempo']]
compostos_n_moa
# Out:
#         composto  n_moa dose  tempo
# 7      8b87a7a83      1   D1     48
# 16     87d714366      2   D1     48
# 25     cacb2b860      0   D1     48
# 38     cacb2b860      0   D1     24
# 40     cacb2b860      0   D2     24
# ...          ...    ...  ...    ...
# 23793  cacb2b860      0   D2     48
# 23802  87d714366      2   D1     24
# 23805  5628cb3ee      1   D2     48
# 23811  cacb2b860      0   D2     48
# 23812  8b87a7a83      1   D1     24
#
# [3235 rows x 4 columns]

# %% [markdown]
# # Aula 5

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
#
# [5 rows x 883 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x=dados_combinados.select_dtypes('float64')
y=dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify= y, random_state = 927)


modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino ,y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6323745538526139

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dumy = DummyClassifier('most_frequent')
modelo_dumy.fit(x_treino, y_treino)
previsao_dumy = modelo_dumy.predict(x_teste)

accuracy_score(y_teste, previsao_dumy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize = True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

x=dados_combinados.select_dtypes('float64')
y=dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify= y, random_state = 927)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.606970396808734

# %%
x=dados_combinados.select_dtypes('float64')
y=dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify= y, random_state = 927)

teste=[]
treino=[]

for i in range(1, 15): 
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.606970396808734,
#  0.612639093008608,
#  0.614948561830779,
#  0.6206172580306529,
#  0.6256560990972077,
#  0.622086920008398,
#  0.6275456644971656,
#  0.6225068234306109,
#  0.6260760025194205,
#  0.6164182238085241,
#  0.6187276926306949,
#  0.6136888515641402]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6192850768988505,
#  0.6249015799695554,
#  0.634034958794814,
#  0.642066033279093,
#  0.6575507847357094,
#  0.6705159834129442,
#  0.6844260143824471,
#  0.7045824366175004,
#  0.7251062936328802,
#  0.7444228649414729,
#  0.7608524486903575,
#  0.7815337777544485]

# %%
sns.lineplot(x = range(1,15), y= teste, label = 'teste')
sns.lineplot(x = range(1,15), y= treino, label = 'treino')

#overfitting

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto     g_0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 887 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x= dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'tempo_24', 'tempo_48', 'tempo_72', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y= dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify= y, random_state = 927)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6890615158513542

# %%
x= dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'tempo_24', 'tempo_48', 'tempo_72', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y= dados_combinados['n_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify= y, random_state = 927)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6483308838967038
